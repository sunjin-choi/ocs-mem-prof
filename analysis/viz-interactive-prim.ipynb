# %%
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d  # noqa: F401

from sklearn.cluster import OPTICS
from sklearn import datasets
from sklearn.cluster import KMeans

from viztools import draw_scatter_plot, data_loader

# %%
trace_dir = "/tmp/tpcds-trace"

machine_name = "n2-standard-8"
query_data = "scale_1_rngseed_0"
query_limit = 100

query_name = "distinct"

data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
fig = draw_scatter_plot(data, True, int(1e4), 0, True, 10, 1)
# Out:
# trace plot of execution time 0.000% to 0.095%

# %%
query_name = "cross_join"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(1e6), 0, True, 10)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 query_name = "cross_join"
# ----> 2 data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
#       3 draw_scatter_plot(data, True, 1000000, 0, True, 10)
#
# File ~/sky_workdir/ocs-mem-prof/analysis/viztools.py:67, in data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
#      64         skip_rows += 1
#      66 # Load the data from the CSV file, skipping the found number of rows
# ---> 67 data = pd.read_csv(file_path(query_name), skiprows=range(0, skip_rows + 1), sep=',')
#      68 return data[["timestamp", "address", "count"]]
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:586, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
query_name = "range_scan"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(1e6), int(1e6), True, 10)
# Out:
# trace plot of execution time 9.511577634970951% to 19.023155269941903%

# %%
query_name = "equijoin"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(5e6), int(1e6), True, 10)
# Out:
# trace plot of execution time 9.160448554188084% to 54.9626913251285%

# %%
query_name = "sort_order_by"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(1e6), int(1e6), True, 10)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 query_name = "sort_order_by"
# ----> 2 data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
#       3 draw_scatter_plot(data, True, int(1e6), int(1e6), True, 10)
#
# File ~/sky_workdir/ocs-mem-prof/analysis/viztools.py:67, in data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
#      64         skip_rows += 1
#      66 # Load the data from the CSV file, skipping the found number of rows
# ---> 67 data = pd.read_csv(file_path(query_name), skiprows=range(0, skip_rows + 1), sep=',')
#      68 return data[["timestamp", "address", "count"]]
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File /opt/conda/envs/jupyter/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:586, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
query_name = "single-column_aggregation_group_by"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(1e6), int(1e6), True, 10)
# Out:
# trace plot of execution time 9.448495119285361% to 18.896990238570723%

# %%
query_name = "full_scan"
data = data_loader(trace_dir, query_name, query_data, query_limit, machine_name)
draw_scatter_plot(data, True, int(1e6), 0, True, 10)
