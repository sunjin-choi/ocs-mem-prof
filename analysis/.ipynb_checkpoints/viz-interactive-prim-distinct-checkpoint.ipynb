# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import OPTICS
import sys


def apply_window_sum(data, group_size):
    """
    Apply a summing window of given size to the data for coarser granular analysis.
    The function groups data into batches of 'group_size' and then sums them.
    """
    # Create a 'group' column that identifies which group each row belongs to
    data['group'] = data.index // group_size

    # Group by 'group' and sum up the other columns
    windowed_data = data.groupby('group').agg({
        'timestamp': 'mean',  # or 'first', depending on what you want
        'address': 'first',  # keeping the first address for each group
        'count': 'sum'
    }).reset_index(drop=True)

    return windowed_data

def select_top_n(data, n):
    """
    Select the top n most frequently accessed addresses.
    """
    return data.groupby('address').sum().sort_values(by='count', ascending=False).head(n)

def trim_data(data, window_size, start_idx):
    """
    Trim the data to the given window size.
    """

    # Trim the data to the given window size
    data = data.iloc[start_idx:start_idx+window_size]

    # Reset the index
    data = data.reset_index(drop=True)
    
    return data

def extract_cols(data):
    x = data['timestamp']
    y = (data['address']).apply(lambda x: int(str(x), 16))
    z = data['count']
    return x, y, z
# Out:
# Requirement already satisfied: pandas in /opt/conda/envs/jupyter/lib/python3.9/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/conda/envs/jupyter/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in /opt/conda/envs/jupyter/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/jupyter/lib/python3.9/site-packages (from scikit-learn) (3.2.0)

# %%
from pathlib import Path

trace_dir = "/tmp/tpcds-trace"

machine_name = "n2-standard-8"
query_data = "scale_1_rngseed_0"
query_limit = "limit-100"

trace_dir = "/tmp/tpcds-trace"

def file_path(query_name, query_data=query_data, query_limit=query_limit, machine_name=machine_name):
    return Path(trace_dir) / f"query_{query_name}_{query_data}_{machine_name}-{query_limit}.csv"

# %%
from pathlib import Path

skip_rows = 0
with open(file_path("distinct"), 'r') as f:
    for line in f:
        if "---- <application exited with code 0> ----" in line:
            break
        skip_rows += 1

# Load the data from the CSV file, skipping the found number of rows
data = pd.read_csv(file_path("distinct"), skiprows=range(0, skip_rows + 1), sep=',')

data.head()
# Out:
#     timestamp        address  count   type
# 0  1050694283  2187027609528      8   Load
# 1  1050694283  2187027609528      8  Store
# 2  1050694283  2187027609527      8   Load
# 3  1050694283  2187027609527      8  Store
# 4  1050694283  2187027609018      3   Load

# %%
data_plot = trim_data(data, 1000000, 0)
x, y, z = extract_cols(data_plot)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a wireframe 3D plot
ax.scatter(x, y, z, c='b', marker='o')

# Set labels for the axes
ax.set_xlabel('timestamp')
ax.set_ylabel('address')
ax.set_zlabel('frequency')
ax.set_title('Stores and Loads')

plt.show()

# %%
def draw_scatter_plot(data, length, start_idx):
    data_plot = trim_data(data, length, start_idx)
    x, y, z = extract_cols(data_plot)
    
    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    # Create a wireframe 3D plot
    ax.scatter(x, y, z, c='b', marker='o')
    
    # Set labels for the axes
    ax.set_xlabel('timestamp')
    ax.set_ylabel('address')
    ax.set_zlabel('frequency')
    ax.set_title('Stores and Loads')

# %%
# imports
import matplotlib.pyplot as plt

import mpl_toolkits.mplot3d  # noqa: F401
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn.cluster import KMeans

estimators = [
    ("k_means_10", KMeans(n_clusters=10, n_init="auto")),
    #("k_means_8", KMeans(n_clusters=8, n_init="auto")),
    #("k_means_3", KMeans(n_clusters=3, n_init="auto")),
]

data_plot = trim_data(data, 10000, 0)
x, y, z = extract_cols(data_plot)

fig = plt.figure(figsize=(10, 8))
titles = ["10 clusters", "8 clusters", "3 clusters"]
for idx, ((name, est), title) in enumerate(zip(estimators, titles)):
    ax = fig.add_subplot(2, 2, idx + 1, projection="3d", elev=48, azim=134)
    est.fit(data_all_accesses)
    labels = est.labels_

    ax.scatter(x, y, z, c=labels.astype(float), edgecolor="k")

    ax.xaxis.set_ticklabels([])
    ax.yaxis.set_ticklabels([])
    ax.zaxis.set_ticklabels([])
    ax.set_xlabel("Timestamp")
    ax.set_ylabel("Address")
    ax.set_zlabel("Count")
    ax.set_title(title)
